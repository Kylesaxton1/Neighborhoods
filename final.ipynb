# %% [markdown]
# **Neighborhoods in Pittsburgh**

# %%
import math
import pandas as pd
# %matplotlib inline

# %%
crime = pd.read_csv("final-project/crime-data.csv", index_col = "ARRESTTIME", parse_dates = True)
crime.groupby("INCIDENTNEIGHBORHOOD")
crime.head(10)
# Out:
#                           PK       CCR   AGE GENDER RACE  \
# ARRESTTIME
# 2016-08-24 12:20:00  1975272  16158872  42.0      F    B
# 2016-08-03 14:55:00  1974456  16144120  31.0      M    W
# 2016-08-03 16:45:00  1974466  16144165  63.0      F    B
# 2016-08-05 02:36:00  1974550  16145257  25.0      F    W
# 2016-08-06 02:00:00  1974596  16145962  25.0      M    B
# 2016-08-15 13:30:00  1974556  16144301  45.0      M    W
# 2016-08-16 13:00:00  1974628  16147655  29.0      M    W
# 2016-08-16 04:25:00  1974607  16146037  21.0      F    B
# 2016-08-29 17:55:00  1974643  16132537  17.0      M    B
# 2016-08-23 13:36:00  1974647  16138646  14.0      M    B
#
#                                                        ARRESTLOCATION  \
# ARRESTTIME
# 2016-08-24 12:20:00         4700 Block Centre AV Pittsburgh, PA 15213
# 2016-08-03 14:55:00  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2016-08-03 16:45:00        900 Block Freeport RD Fox Chapel, PA 15238
# ...

# %%
playground = pd.read_csv("final-project/playground-data.csv",parse_dates = True)
playground.groupby("neighborhood")
playground.head(10)
# Out:
#            id                          name     equipment_type  manufacturer  \
# 0  1780722587          Able Long Playground   Play Area 2 to 5  Little Tykes
# 1   702514290         North Ave. Playground   Play Area 2 to 5     Playworld
# 2  1267038491  Vietnam Veteran's Playground              Slide  Little Tykes
# 3    14898932  Schenley Overlook Playground       Swing 2 Bays  Little Tykes
# 4   204832406  Schenley Overlook Playground              Slide  Little Tykes
# 5   788191865          Chartiers Playground       Swing 2 Bays  Little Tykes
# 6  1387089430          Chartiers Playground       Swing 2 Bays  Little Tykes
# 7  1838217886          Chartiers Playground   Play Area 2 to 5  Little Tykes
# 8  1315630398          Chartiers Playground  Play Area 5 to 12  Little Tykes
# 9  1603952265          Chartiers Playground              Whirl           NaN
#
#   safety_surface_type ada_accessible  street_number             street  \
# ...
